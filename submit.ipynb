# %%
import pandas as pd

# %%
df=pd.read_excel('Exercise Data.xlsx')
df.head()
# Out:
#   Unnamed: 0    Unnamed: 1                Unnamed: 2  \
# 0      Month  Contribution  Amount won by the bidder
# 1          1          2000                     40000
# 2          2          2000                     42000
# 3          3          2000                     45000
# 4          4          2000                     48000
#
#                        Unnamed: 3                     Unnamed: 4  \
# 0  Chit fund organizer commission  Net amount recd by Bid winner
# 1                            2500                          37500
# 2                            2500                          39500
# 3                            2500                          42500
# 4                            2500                          45500
#
#                                  Unnamed: 5
# 0  Amount returned to everyone in the group
# 1                                       400
# 2                                       320
# 3                                       200
# ...

# %%
new_header = df.iloc[0]

# %%
df = df[1:]

# %%
df.columns = new_header

# %%
df.head()
# Out:
# 0 Month Contribution Amount won by the bidder Chit fund organizer commission  \
# 1     1         2000                    40000                           2500
# 2     2         2000                    42000                           2500
# 3     3         2000                    45000                           2500
# 4     4         2000                    48000                           2500
# 5     5         2000                    40000                           2500
#
# 0 Net amount recd by Bid winner Amount returned to everyone in the group
# 1                         37500                                      400
# 2                         39500                                      320
# 3                         42500                                      200
# 4                         45500                                       80
# 5                         37500                                      400

# %%
x=df['Amount returned to everyone in the group'].sum()
x
# Out:
# 6200

# %%
df2=df['Contribution']
net_Contribution=df2.sum()
net_Contribution
# Out:
# 50000

# %%
df['profit_each'] =df['Net amount recd by Bid winner']+x
# Out:
# <ipython-input-13-e30d5e4d0438>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['profit_each'] =df['Net amount recd by Bid winner']+x

# %%
df
# Out:
# 0  Month Contribution Amount won by the bidder Chit fund organizer commission  \
# 1      1         2000                    40000                           2500
# 2      2         2000                    42000                           2500
# 3      3         2000                    45000                           2500
# 4      4         2000                    48000                           2500
# 5      5         2000                    40000                           2500
# 6      6         2000                    42000                           2500
# 7      7         2000                    43000                           2500
# 8      8         2000                    44000                           2500
# 9      9         2000                    40000                           2500
# 10    10         2000                    42000                           2500
# 11    11         2000                    45000                           2500
# ...

# %%
df.to_excel('saved_file.xlsx', index = False)
